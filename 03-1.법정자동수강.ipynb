# %%
driver.find_element(By.CSS_SELECTOR, "#p_id_select").click()
time.sleep(1)
driver.find_element(By.CSS_SELECTOR, "#p_id_select ul li:nth-child(1)").click()
time.sleep(1)

for i in range(1, 18):
        driver.find_element(By.CSS_SELECTOR, "#s_id_select > p").click()
        time.sleep(1)
        driver.find_element(By.CSS_SELECTOR, f"#s_id_select ul > li:nth-child({i})").click()
        time.sleep(1)
        driver.find_element(By.CSS_SELECTOR, "body > div > div.center > div:nth-child(2) > div.lecture_wrap > div.sub_content2 > div > table > tbody > tr > td:nth-child(8) > span > a").click()
        time.sleep(1)                 
        driver.switch_to.window(driver.window_handles[1])
        time.sleep(2.5)
        driver.close()
        time.sleep(1)
        driver.switch_to.window(driver.window_handles[0])
driver.close()
